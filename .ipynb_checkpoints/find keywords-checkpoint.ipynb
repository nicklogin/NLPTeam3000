# %%
import pandas as pd

# %%
import xml.etree.ElementTree as et

# %%
import os

# %%
import re

# %%
xtree = et.parse("development/SentiRuEval_rest_train.xml")

# %%
os.listdir('development')
# Out:
# ['.~lock.SentiRuEval_rest_train.xml#',
#  'Food_words.txt',
#  'SentiRuEval_rest_train.xml',
#  'Service_words.txt']

# %%
root = xtree.getroot()

# %%
data = []
columns = ['id', 'food', 'service', 'text']

# %%
for review in root:
    text_id = int(review.attrib['id'])
    
    scores = review.find('scores')
    
    food = int(scores.find('food').text)
    service = int(scores.find('service').text)
    
    text = review.find('text').text
    
    data.append({'id': text_id,
                'food': food,
                'service': service,
                'text': text})
    

df = pd.DataFrame(data, columns=columns)
df = df.set_index('id')

# %%
df.head()
# Out:
#        food  service                                               text
# id
# 17600     8        8  И пускай на меня не обижается наш прославленны...
# 23518     9       10  - Здравствуйте. Виа Д’Арженто! - Добрый вечер,...
# 27221     9        1  Советую вам уволить Вашего метродотеля Елену, ...
# 29097     8        9  отличный средне вековый интеръер. Приятное обс...
# 23065    10        8  Ужинали в ресторане Баден-Баден 6 марта . Импо...

# %%
texts = df['text']
y = df[['food', 'service']].applymap(lambda x: 1 if x > 5 else 0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Для начала обучим простой классифаер текстов:

# %%
import numpy as np

# %%
vectorizer = TfidfVectorizer()

texts_train, texts_test, y_train, y_test = train_test_split(texts, y, test_size=0.2, random_state=42)

X_train = vectorizer.fit_transform(texts_train)
X_test = vectorizer.transform(texts_test)

parameter_grid = {"penalty": ["l1", "l2", "elasticnet"],
                 "alpha": [10**i for i in range(-10, 1)]}

clf_food = GridSearchCV(SGDClassifier(random_state=42, n_jobs=2, loss="log"), parameter_grid, n_jobs=2)
clf_food.fit(X_train, y_train["food"])
clf_food.score(X_test, y_test["food"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# 0.8347780404517993

# %%
clf_service = GridSearchCV(SGDClassifier(random_state=42, n_jobs=2, loss="log"), parameter_grid, n_jobs=2)
clf_service.fit(X_train, y_train["service"])
clf_service.score(X_test, y_test["service"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# 0.8623588127134226

# %% [markdown]
# Продумаем простую реализацию поиска тональных слов - для каждого слова смотрим контексты, включающие его длины 5 и если во всех контекстах вероятность положительного или отрицательного класса больше определённого значения, считаем это слово тональным

# %%
clf_food.predict_proba(vectorizer.transform(["Невкусная еда"]))
# Out:
# array([[0.96103279, 0.03896721]])

# %%
clf_food.predict_proba(vectorizer.transform(['Вкусная еда']))
# Out:
# array([[0.00563599, 0.99436401]])

# %%
clf_service.predict_proba(vectorizer.transform(['Отличное обслуживание']))
# Out:
# array([[0.02212955, 0.97787045]])

# %%
clf_service.predict_proba(vectorizer.transform(['Ужасное обслуживание']))
# Out:
# array([[0.99441738, 0.00558262]])

# %% [markdown]
# Загрузим наши размеченные тексты:

# %%
def get_prepared_data(conllu_data_folder, tonal_folder):
    texts = []
    food_pos = []
    food_neg = []
    service_pos = []
    service_neg = []
    
    for file in os.listdir(conllu_data_folder):
        if file.endswith('.tsv'):
            sent_id = 0

            sentences = []
            
            text = open(os.path.join(conllu_data_folder, file), 'r', encoding='utf-8').read()

            for line in text.splitlines()[1:]:
                if '# sent_id' in line:
                    sent_id = re.search("sent_id = ([0-9]+)", line).group(1)
                    sentences.append([])
                try:
                    token_id, token, lemma, pos, *other = line.split('\t')
                except:
                    continue
                if token:
                    sentences[-1].append((sent_id, int(token_id), token))
            
            markup = open(os.path.join(tonal_folder, file[:-4]+".tsv"), 'r', encoding='utf-8').read()
            
            food_neg_ids = set()
            food_pos_ids = set()
            service_neg_ids = set()
            service_pos_ids = set()
            
            for line in markup.splitlines():
                line = line.strip()
                if line:
                    sent_id, token_ids, aspect, mark = line.split('\t')
                    token_ids = [int(i) for i in token_ids.split(',')]
                    token_ids = [i for i in range(token_ids[0], token_ids[-1])]
                    if aspect == 'Food' and mark == '1':
                        for token_id in token_ids:
                            food_pos_ids.add((sent_id, token_id))
                    elif aspect == 'Food' and mark == '0':
                        for token_id in token_ids:
                            food_neg_ids.add((sent_id, token_id))
                    elif aspect == 'Service' and mark == '1':
                        for token_id in token_ids:
                            service_pos_ids.add((sent_id, token_id))
                    elif aspect == 'Service' and mark == '0':
                        for token_id in token_ids:
                            service_neg_ids.add((sent_id, token_id))
                    
            for sent in sentences:
                for sent_id, token_id, token in sent:
                    for lst, hashmap in zip([food_neg, food_pos, service_neg, service_pos],
                        [food_neg_ids, food_pos_ids, service_neg_ids, service_pos_ids]):
                        if (sent_id, token_id) in hashmap:
                            lst.append(1)
                        else:
                            lst.append(0)
            
            sentences = [j[2] for i in sentences for j in i]
            print(sentences)
            texts.append(sentences)
            
    return texts, food_pos, food_neg, service_pos, service_neg

# %%
data, food_pos, food_neg, service_pos, service_neg  = get_prepared_data(conllu_data_folder="conllu_data",
                                                                       tonal_folder="разметка_финал")
# Out:
# ['Были', 'сегодня', 'первый', 'раз', '!', 'Все', 'очень', 'понравилось', '.', 'И', 'место', 'на', 'диванчиках', 'нашлось', ',', 'и', 'официантка', 'очень', 'приветливая', ',', 'но', 'ненавязчивая', ',', 'интерьер', 'приятный', ',', 'живая', 'музыка', 'тоже', 'расслабляет', ',', 'вполне', 'и', 'под', 'нее', 'можно', 'вести', 'беседу', '.', 'Обслуживание', 'оперативное', ',', 'ждать', '1', '-', '2', 'минуты', 'пиво', ',', 'гренки', 'чуть', 'дольше', ',', 'пиво', 'отличное', '!', '!', '!', 'я', 'в', 'восторге', '!', '!', '!', 'обстановка', 'очень', 'уютная', '.', 'а', 'еще', 'радует', 'что', 'недалеко', 'от', 'дома', 'такое', 'прекрасное', 'заведение', 'есть', '!', '!', '!']
# ['Зашли', 'в', '"', 'аппетит', '"', 'случайно.', 'Не', 'смотря', 'на', 'то', ',что', 'был', 'будний', 'день', '(', 'вторник', '14', 'сентября', ')', 'и', 'достаточно', 'много', 'народа', ',', 'все', 'же', 'решили', 'остаться.', 'нас', 'встретил', 'менеджер', '-', 'темноволосая', 'стройная', 'девушка', ',', 'проводила', 'к', 'столу', 'и', 'дала', 'меню', '.', '.', '.', 'Спустя', '5', 'минут', 'пришла', 'официантка', ',', 'приняла', 'заказ', 'и', 'удалилась', '.', '.', '.', 'Посмотрев', 'вокруг', 'мы', 'подумали', 'что', 'ждать', 'придется', 'долго', '-', 'ресторан', 'был', 'полон', ',', 'однако', 'мы', 'ошиблись', ',', 'ожидание', 'было', 'недолгим', '-', 'вполне', 'приемлимым', 'для', 'любого', 'заведения', ',', 'за', 'приятной', 'беседой', 'мы', 'не', 'заметили', 'как', 'прошло', 'время', '.', '.', '.', 'Бизнес', 'ланч', ',', 'на', 'удивление', ',', 'оказался', 'очень', 'вкусным', 'и', 'сытным', '-', 'вполне', 'соответствует', 'своей', 'цене', '.', 'В', 'общем', 'очень', 'хорошее', 'место', ',', 'разнообразное', 'вкусное', 'меню', ',', 'приемлемые', 'цены', 'и', 'высокое', 'качество', 'обслуживания', '!', 'нам', 'очень', 'все', 'понравилось', '.', 'спасибо', 'этому', 'заведению', '!', 'обязательно', 'придем', 'на', 'выходных', '.']
# ['Неделю', 'назад', 'зашли', 'посмотреть', 'на', 'новое', 'заведение', '.', 'Столик', 'заказали', ',', 'но', 'можно', 'было', 'и', 'не', 'заказывать', ',', 'свободные', 'столы', 'были', '.', 'В', 'ресторане', '2', 'зала', 'и', 'комната', 'для', 'караоке', '(', 'ее', 'увидеть', 'не', 'удалось', ',', 'работает', 'не', 'каждый', 'день', ')', '.', 'Интерьер', 'в', 'нашем', 'зале', 'нам', 'понравился', '-', 'уютно', ',', 'красивая', 'мебель', '.', 'Меню', 'не', 'очень', 'большое', ',', 'цены', 'среднегородские', '.', 'Отсутствие', 'некоторых', 'заказанных', 'салатов', 'нам', 'объяснили', 'большим', 'спросом', ':', '-', ')', 'Несколько', 'удивило', 'огромное', 'количество', 'обслуживающего', 'персонала', 'в', 'пересчете', 'на', 'кв.м.', 'и', 'посетителя', ',', 'наш', 'стол', 'обслуживало', 'двое', ',', 'хотя', 'нас', 'было', 'за', 'столом', 'всего', '5', 'чел', '.', 'По', 'залам', 'постоянно', 'ходит', 'персонал', ',', 'у', 'входа', 'стоит', 'несколько', '"', 'встречающих', '"', '.', 'Видимо', 'администрация', 'кризис', 'пока', 'не', 'чувствует', '.', '.', '.', 'По', 'качеству', 'салатов', 'претензий', 'не', 'было', ',', 'а', 'вот', 'десерты', 'не', 'впечатлили', ',', 'нам', 'показалось', ',', 'что', 'готовятся', 'они', 'не', 'в', 'ресторане', '.', 'Наверное', 'надо', 'будет', 'зайти', 'еще', ',', 'чтобы', 'увидеть', 'динамику', 'развития', '.', '.', '.']
# ['мы', 'посетили', 'ресторан', '10', 'марта', '.', 'впечатления', 'остались', 'самые', 'замечательные', '.', 'я', 'тут', 'почитала', 'предыдущие', 'отзывы', '.', 'не', 'знаю', ',', 'но', 'мне', 'кажется', ',', 'что', 'это', 'происки', 'конкурентов', '!', ':', ')', ')', 'я', 'сама', 'в', 'паулайнере', 'была', 'не', 'в', 'первый', 'раз', ',', 'и', 'всегда', 'тут', 'хорошее', 'обслуживание', 'и', 'вкусная', 'кухня', '.', 'про', 'пиво', 'вообще', 'говорить', 'нечего', ',', 'оно', 'выше', 'всех', 'похвал', '!', 'да', ',', 'еще', 'по', 'поводу', 'столиков', '.', '.', '.', 'у', 'нас', 'никогда', 'не', 'возникало', 'проблем', 'с', 'его', 'заказом', '.', '.', '.', 'этот', 'раз', 'вообще', 'заказывали', 'в', 'этот', 'же', 'день', '.', 'персонал', 'вежливый', ',', 'никто', 'нам', 'не', 'хамил', 'и', 'не', 'обсчитывал', '.', 'обслуживала', 'наш', 'столик', 'девушка', 'Мария', ',', 'еще', 'раз', 'хочется', 'сказать', 'ей', 'большое', 'спасибо', '!', 'очень', 'приветливая', 'девушка', '!', 'у', 'нас', 'на', 'столе', 'никогда', 'не', 'было', 'больше', '2', 'окрков', 'в', 'пепельнице', ',', 'с', 'такой', 'частотой', 'она', 'их', 'меняла', '.', 'была', 'очень', 'приветлива', ',', 'посоянно', 'к', 'нам', 'подходила', ',', 'уточняла', 'не', 'нужно', 'ли', 'чего-нибудь', 'еще', '.', 'и', 'в', 'то', 'же', 'время', 'это', 'не', 'выглядело', 'как-то', 'навязчиво', '.', 'горячее', 'принесли', 'через', '15', 'минут', 'после', 'заказа', ',', 'мы', 'даже', 'и', 'не', 'ожидали', 'такой', 'оперативности', '!', 'в', 'общем', ',', 'впечатления', 'остались', 'самые', 'положительные', '!', '(', 'это', 'впрочем', ',', 'как', 'всегда', '!', ')', 'обязательно', 'будем', 'приходить', 'сюда', 'ещеи', 'еще', '!']
# ['Никогда', 'не', 'писал', 'отзывы', ',', 'но', 'тут', '-', 'просто', 'обязан', '!', 'Искали', 'с', 'друзьями', 'хорошее', 'местечко', 'на', 'севере', ',', 'чтобы', 'было', 'уютно', ',', 'не', 'сильно', 'шумно', 'как', 'в', 'популярных', 'кафе-барах', ',', 'но', 'и', 'не', 'ресторан', '-', 'в', 'общем', 'приличный', 'паб', 'для', 'хорошей', 'выпивки', 'и', 'закуски', '.', 'И', 'это', 'место', 'именно', 'то', ',', 'что', 'надо', '!', 'И', 'даже', 'лучше', '.', 'Правда', 'сам', 'факт', 'того', ',', 'что', 'нам', 'удалось', 'посидеть', 'в', 'этом', 'заведении', 'считаю', 'везением', '-', 'увидели', 'свободный', 'столик', 'почти', 'в', 'углу', '-', 'просто', 'повезло', 'что', 'он', 'был', 'свободен', '.', 'Поэтому', 'теперь', 'перед', 'походом', 'сюда', '-', 'будем', 'бронировать', '.', 'Пиво', 'не', 'пробовали', '-', 'поэтому', 'ничего', 'не', 'скажу', '.', 'Пробовали', 'коктейли', '-', 'прекрасные', ',', 'чувствуется', ',', 'что', 'сделаны', 'из', 'хороших', 'напитков', ',', 'как', 'положено', '.', 'Отдельное', 'спасибо', 'официантке', '-', 'она', 'просто', 'угадывала', 'наши', 'желания', ',', 'и', 'советовала', 'то', ',', 'что', 'нам', 'и', 'хотелось', '.', 'Обслуживание', '10', 'баллов', '.', 'Еда', 'вкусная', '.', 'Еще', 'стоит', 'отметить', 'прекрасный', ',', 'уютный', 'и', 'стильный', 'интерьер', 'и', 'безупречно', 'подобранный', 'музыкальный', 'фон', '(', 'для', 'тех', ',', 'кому', 'это', 'важно', ')', '.', 'Ощущение', 'было', ',', 'что', 'я', 'дома', ',', 'и', 'все', 'свои', '.', 'Спасибо', ',', '"', 'радио', '"', 'за', 'отличный', 'вечер', '!']
# ['Сегодня', 'мы', 'всей', 'семьей', 'посетили', 'ресторан', 'Марчеллис', '.', 'Были', 'впервые', ',', 'остались', 'довольны', ',', 'кухня', 'и', 'обслуживание', 'превзошли', 'наши', 'ожидание', ',', 'не', 'везде', 'встречают', 'так', ',', 'как', 'будто', 'мы', 'пришли', 'в', 'гости', 'к', 'друзьям', ')', ')', ')', ')', 'Пришли', 'покушать', 'около', '16', 'часов', ',', 'народу', 'полный', 'зал', ',', 'стол', 'не', 'заказывали', ',', 'поэтому', 'пришлось', 'сесть', 'очень', 'близко', 'к', 'двери', ',', 'но', 'так', 'как', 'у', 'нас', 'маленькие', 'дети', ',', 'переживали', 'что', 'детей', 'продует', '.', 'Девушка', '-', 'администратор', 'вошла', 'в', 'положение', ',', 'и', 'моментально', 'решила', 'вопрос', '(', 'уже', 'через', 'пару', 'минут', 'мы', 'расположились', 'в', 'центре', 'зала', 'на', 'мягких', 'диванах', ')', 'и', 'тут', 'же', 'сама', 'приняла', 'заказ', '.', 'Обстановка', 'в', 'ресторане', 'вообще', 'очень', 'приятная', 'и', 'домашняя', ',', 'грязные', 'тарелки', 'исчезали', 'со', 'стола', 'незаметно', ',', 'весь', 'персонал', 'приятные', 'и', 'улыбчивые', 'ребята', '.', 'По', 'кухне', ':', 'очень', 'понравился', 'палтус', 'со', 'шпинатом', ',', 'такого', 'нежного', 'палтуса', 'мы', 'нигде', 'не', 'встречали', ',', 'впечатлил', 'салат', 'из', 'запеченых', 'овощей', ')', ')', 'в', 'основном', 'все', 'порадовало', ',', 'ушли', 'довольные', 'и', 'сытые', '.', 'А', 'еще', ',', 'мы', 'не', 'стали', 'заказывать', 'десерты', ',', 'т.', 'к', '.', 'наш', 'ужин', 'получился', 'довольно', 'сытным', ',', 'но', ',', 'приятно', 'удивились', ',', 'когда', 'нас', 'угостили', 'вкусняшками', 'в', 'маленьких', 'рюмочках', ',', '(', 'по-моему', 'панакота', ')', '.', 'Теперь', 'мы', 'частые', 'гости', 'в', 'этом', 'заведении', ',', 'все', 'семейные', 'праздники', 'будем', 'отмечать', 'в', 'Марчеллисе', '.', 'Ребята', ',', 'так', 'держать', ',', 'спасибо', 'большое', '.', 'P.', 'S.', ':', 'не', 'могу', 'не', 'отметить', 'трепетного', 'отношения', 'к', 'детям', 'в', 'этом', 'ресторане', ',', 'моим', 'малышам', 'там', 'настолько', 'понравилось', ',', 'еле', 'увели', 'домой', ')', ')', ')', ')']
# ['Отличное', 'кафе', '!', '!', '!', '!', 'Отмечала', 'в', 'нем', 'свой', 'день', 'рождения', 'с', 'друзьями', '.', 'Все', 'было', 'замечательно', '-', 'вкусная', 'и', 'обильная', 'еда', ',', 'большие', 'блюда', ',', 'обстановка', ',', 'вежливая', 'администратор', 'Александра', '.', 'Небольшое', 'уютное', 'кафе', '.', 'Очень', 'низкие', 'цены', '(', 'и', 'это', 'с', 'учетом', 'того', ',', 'что', 'место', 'находится', 'на', 'Невском', 'проспекте', ')', '.', 'Я', 'уже', 'не', 'первый', 'раз', 'сюда', 'хожу', 'и', 'всегда', 'очень', 'довольна', '.', 'Очень', 'вкусные', 'хачапури', 'с', 'сыром', ',', 'вкусный', 'лосось', '(', 'кусок', 'очень', 'большой', 'и', 'сытный', ')', '.', 'И', 'много', 'другой', 'вкусной', 'еды', '.', 'У', 'меня', 'все', 'друзья', 'решили', 'сюда', 'прийти', 'еще', 'не', 'раз', '.', 'Если', 'говорить', 'о', 'минусах', ':', 'Минус', ',', 'пожалуй', ',', 'один', ':', 'Внизу', 'не', 'очень', 'красивый', 'антураж', '.', 'ПО', 'крайней', 'мере', ',', 'мне', 'не', 'очень', 'нравится', '.', 'Но', ',', 'наверное', ',', 'это', 'на', 'любителя', '.', 'На', 'верхнем', 'этаже', 'все', 'супер', '!', '!', '!', '!', 'НО', 'зато', 'внизу', 'можно', 'попеть', 'караоке', '!', 'Есть', 'ооочень', 'вкусный', 'кальян', '.', 'В', 'общем', ',', 'порекомендую', 'это', 'место', 'всем', 'тем', ',', 'кто', 'хочет', 'вкусно', ',', 'сытно', 'и', 'не', 'очень', 'дорого', 'отметить', 'какой-нибудь', 'праздник', 'или', 'просто', 'посидеть', 'вдвоем', 'в', 'уютной', 'обстановке', '.', 'Очень', '-', 'очень', 'довольна', '!', '!', '!', '!']
# ['Приятный', 'итальянский', 'ресторанчик', 'без', 'претензий', '.', 'Из', 'минусов', 'по', 'обслуживанию', 'только', 'то', ',', 'что', 'долго', 'ждали', 'официанта', 'с', 'меню', '.', 'Интерьер', 'простой', 'как', 'внутри', ',', 'так', 'и', 'снаружи', '.', 'Из', 'блюд', 'заказывали', 'томатный', 'суп', ',', 'ризотто', 'с', 'белыми', 'грибами', ',', 'пасту', 'с', 'креветками', 'и', 'Цезарь', '.', 'Порции', 'достаточно', 'большие', ';', 'все', 'было', 'вкусно', ',', 'а', 'вот', 'Цезарь', 'с', 'курицей', 'очень', 'расстроил', ',', 'соус', 'был', 'невкусный', 'с', 'рыбным', 'запахом', '.', 'Хорошее', 'место', 'для', 'вкусной', 'трапезы', 'итальянской', 'кухни', 'по', 'умеренной', 'цене', '.']
# ['Я', 'редко', 'пишу', 'отрицательные', 'отзывы', ',', 'но', 'в', 'данном', 'случае', 'просто', 'считаю', 'это', 'делом', 'принципа', '.', 'Зашли', 'с', 'другом', 'в', 'воскременье', 'вечером', '.', 'Скажем', 'так', ',', 'такого', 'отвратительного', 'впечатления', 'от', 'посещения', 'ресторана', '/', 'паба', 'у', 'меня', 'давное', 'не', 'было', '.', 'Встретила', 'и', 'обслуживала', 'нас', 'откровенно', 'хамоватая', 'официантка', '.', 'Половина', 'блюд', 'из', 'меню', 'в', 'наличии', 'не', 'было', '.', 'На', 'вопрос', 'почему', 'так', 'официантка', 'ответила', 'с', 'вызовом', ',', 'что', 'вчера', 'все', 'было', ',', 'а', 'сегодня', 'закончилось', '.', 'Я', 'заказал', 'сырные', 'палочки', '.', 'Ждали', 'мы', 'их', ',', 'ждали', ',', 'пришла', 'офицантка', 'и', 'сообщила', 'что', 'она', 'их', 'уронила', 'на', 'пол', ',', 'и', 'что', 'это', 'были', 'последние', 'палочки', 'и', 'вообщем', 'палочек', 'не', 'будет', '.', 'Мне', 'хотелось', 'встать', 'и', 'уйти', ',', 'но', 'так', 'как', 'это', 'единственное', 'место', ',', 'где', 'можно', 'выпить', 'пиво', 'в', 'окрестности', ',', 'пришлось', 'остаться', '.', 'Мой', 'друг', 'заказал', 'цезарь', 'с', 'креветками', '(', 'курицы', 'не', 'оказалось', ')', ',', 'который', 'оказался', 'и', 'на', 'вид', 'и', 'на', 'вкус', 'совершенно', 'отвратительным', '.', 'Потом', 'официантка', 'не', 'слишком', 'вежливо', 'поинтересовалась', 'знаем', 'ли', 'мы', 'что', 'они', 'работают', 'в', 'воскресенье', 'до', '11ти', '.', 'На', 'что', 'мы', 'ответили', '"', 'тепреь', 'знаем', '"', '.', 'Вообщем', 'такие', 'дела', '.', 'Ходить', 'туда', 'не', 'советую', ',', 'может', 'конечно', 'в', 'более', 'людные', 'дни', 'они', 'поадекватнее', 'персонал', 'ставят', 'и', 'блюда', 'все', 'в', 'наличии', ',', 'но', 'что-то', 'мне', 'подсказывает', 'что', 'врятли', '.']
# ['Ужасный', 'персонал', 'на', 'Невском', 'пр-те', '22', '0', 'особенно', 'если', 'сидеть', 'у', 'окна', '(', 'некурящих', ')', '.', 'Там', 'всегда', 'обслуживают', 'новые', 'официанты', '0', 'плохо', 'знающие', 'меню', '.', 'Приносят', 'не', 'то', 'что', 'заказываешь', '.', 'Хотя', 'должен', 'отметить', '0', 'что', 'не', 'все', 'официанты', 'такие', '0', 'есть', 'всегда', 'вежливые', '0', 'хорошо', 'обученные', '.', 'И', 'девченки', 'что', 'на', 'входе', 'всегда', 'очень', 'аккуратно', 'относятся', 'к', 'клиентам', '.', 'После', '2', 'месяцев', 'обедов', 'в', 'этом', 'заведении', '0', 'и', '4', 'раз', '0', 'когда', 'обед', 'приносли', 'через', 'час', 'после', 'заказа', '0', 'естественно', 'весь', 'остывший', '0', 'больше', 'нет', 'желания', 'заходить', 'сюда', '.', 'Судя', 'по', 'оценкам', 'сервиса', '0', 'я', 'не', 'единственный', '.', 'Ребята', 'если', 'Вам', 'сложно', 'кормить', 'людей', 'в', 'обед', '0', 'пожалуйста', 'не', 'делайте', 'этого', '.']

# %%
data[0]
# Out:
# ['Были',
#  'сегодня',
#  'первый',
#  'раз',
#  '!',
#  'Все',
#  'очень',
#  'понравилось',
#  '.',
#  'И',
#  'место',
#  'на',
#  'диванчиках',
#  'нашлось',
#  ',',
#  'и',
#  'официантка',
#  'очень',
#  'приветливая',
#  ',',
#  'но',
#  'ненавязчивая',
#  ',',
#  'интерьер',
#  'приятный',
#  ',',
#  'живая',
#  'музыка',
#  'тоже',
#  'расслабляет',
#  ',',
#  'вполне',
#  'и',
#  'под',
#  'нее',
#  'можно',
#  'вести',
#  'беседу',
#  '.',
#  'Обслуживание',
#  'оперативное',
#  ',',
#  'ждать',
#  '1',
#  '-',
#  '2',
#  'минуты',
#  'пиво',
#  ',',
#  'гренки',
#  'чуть',
#  'дольше',
#  ',',
#  'пиво',
#  'отличное',
#  '!',
#  '!',
#  '!',
#  'я',
#  'в',
#  'восторге',
#  '!',
#  '!',
#  '!',
#  'обстановка',
#  'очень',
#  'уютная',
#  '.',
#  'а',
#  'еще',
#  'радует',
#  'что',
#  'недалеко',
#  'от',
#  'дома',
#  'такое',
#  'прекрасное',
#  'заведение',
#  'есть',
#  '!',
#  '!',
#  '!']

# %%
len(data)
# Out:
# 10

# %%
def predict_text_proba(texts, clf=clf, vectorizer=vectorizer):
    return clf.predict_proba(vectorizer.transform(texts))

# %%
avg = lambda x: sum(x)/len(x)

def extract_tonal_words(texts, proba_predictor, aspect='food', threshold=0.7, seq_len=3, criterion="min"):
    is_neg = []
    is_pos = []
    for text in data:
        for sent in text:
            for ind, word in sent:
                seqs = [sent[i:i+seq_len] for i in range(ind-seq_len-1,ind)]
                seqs = [" ".join(seq) for seq in seqs]
            probas = proba_predictor(seqs)
            neg_probas = [i[0] for i in probas]
            pos_probas = [i[1] for i in probas]
            
            if criterion == "max":
                neg_proba, pos_proba = max(neg_probas), max(pos_probas)
            elif criterion == 'min':
                neg_proba, pos_proba = min(neg_probas), min(pos_probas)
            elif criterion == 'avg':
                neg_proba, pos_proba = avg(neg_probas), avg(pos_probas)
            else:
                raise Exception
            
            if neg_proba > threshold:
                is_neg.append(1)
            else:
                is_neg.append(0)
            
            if pos_proba > threshold:
                is_pos.append(1)
            else:
                is_pos.append(0)
            
    return neg_probas, pos_probas

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '12943.tsv',
#  '12943.xlsx',
#  '13823.tsv',
#  '13823.xlsx',
#  '20086.tsv',
#  '20086.xlsx',
#  '28083.tsv',
#  '28083.xlsx',
#  '32840.tsv',
#  '32840.xlsx',
#  '32856.tsv',
#  '32856.xlsx',
#  '33591.tsv',
#  '33591.xlsx',
#  '33693.tsv',
#  '33693.xlsx',
#  '35486.tsv',
#  '35486.xlsx',
#  '5648.tsv',
#  '5648.xlsx',
#  'conllu_data',
#  'convert to needed format.ipynb',
#  'convert.py',
#  'development',
#  'example.csv',
#  'find keywords.ipynb',
#  'README.md',
#  'разметка_финал',
#  'условия']

# %% [markdown]
# Подберём наилучшие праметры для предложенного нами алгоритма (порог, длину последовательности, критерий):
